# %%
from vnpy.app.cta_strategy.backtesting import BacktestingEngine, OptimizationSetting
# from vnpy.app.cta_strategy.strategies.atr_rsi_strategy import (
#     AtrRsiStrategy,
# )
from strategies.breaker.r_break_strategy_5 import RBreakStrategy
# from strategies.breaker.break_strategy_back import RBreakStrategy
from strategies.turtle.turtle_strategy_3 import TurtleStrategy

from datetime import datetime

engine = BacktestingEngine()
engine.set_parameters(
    vt_symbol="bu8888.SHFE",
    interval="1m",
    start=datetime(2016, 1, 1),
    end=datetime(2019, 11, 15),
    rate=0.3/10000,
    slippage=0.2,
    size=10,
    pricetick=0.2, # 最小价格变动
    capital=1_000_000,
)
engine.add_strategy(RBreakStrategy, {'fixed_size': 50})

engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
# Out:
# 2019-12-18 23:41:30.590522	开始加载历史数据
# 2019-12-18 23:41:53.055249	历史数据加载完成，数据量：330990
# 2019-12-18 23:41:53.085136	策略初始化完成
# 2019-12-18 23:41:53.085136	开始回放历史数据
# 2019-12-18 23:41:57.620850	历史数据回放结束
# 2019-12-18 23:41:57.620850	开始计算逐日盯市盈亏
# 2019-12-18 23:41:57.629780	逐日盯市盈亏计算完成
# 2019-12-18 23:41:57.630777	开始计算策略统计指标
# 2019-12-18 23:41:57.640797	------------------------------
# 2019-12-18 23:41:57.640797	首个交易日：	2016-01-15
# 2019-12-18 23:41:57.640797	最后交易日：	2019-11-14
# 2019-12-18 23:41:57.640797	总交易日：	945
# 2019-12-18 23:41:57.640797	盈利交易日：	77
# 2019-12-18 23:41:57.640797	亏损交易日：	128
# 2019-12-18 23:41:57.641774	起始资金：	1,000,000.00
# 2019-12-18 23:41:57.641774	结束资金：	905,304.70
# 2019-12-18 23:41:57.641774	总收益率：	-9.47%
# 2019-12-18 23:41:57.641774	年化收益：	-2.40%
# 2019-12-18 23:41:57.641774	最大回撤: 	-159,048.03
# 2019-12-18 23:41:57.641774	百分比最大回撤: -15.82%
# 2019-12-18 23:41:57.641774	最长回撤天数: 	875
# 2019-12-18 23:41:57.641774	总盈亏：	-94,695.30
# 2019-12-18 23:41:57.641774	总手续费：	26,826.30
# 2019-12-18 23:41:57.641774	总滑点：	68,800.00
# 2019-12-18 23:41:57.641774	总成交金额：	894,209,852.00
# 2019-12-18 23:41:57.641774	总成交笔数：	688
# 2019-12-18 23:41:57.641774	日均盈亏：	-100.21
# 2019-12-18 23:41:57.641774	日均手续费：	28.39
# 2019-12-18 23:41:57.641774	日均滑点：	72.80
# 2019-12-18 23:41:57.641774	日均成交金额：	946,253.81
# 2019-12-18 23:41:57.641774	日均成交笔数：	0.728042328042328
# 2019-12-18 23:41:57.641774	日均收益率：	-0.01%
# 2019-12-18 23:41:57.641774	收益标准差：	0.40%
# 2019-12-18 23:41:57.641774	Sharpe Ratio：	-0.41
# 2019-12-18 23:41:57.641774	收益回撤比：	-0.60
# {'start_date': datetime.date(2016, 1, 15),
#  'end_date': datetime.date(2019, 11, 14),
#  'total_days': 945,
#  'profit_days': 77,
#  'loss_days': 128,
#  'capital': 1000000,
#  'end_balance': 905304.7044399998,
#  'max_drawdown': -159048.03049500042,
#  'max_ddpercent': -15.82199706150097,
#  'max_drawdown_duration': 875,
#  'total_net_pnl': -94695.2955600002,
#  'daily_net_pnl': -100.20666196825418,
#  'total_commission': 26826.29556,
#  'daily_commission': 28.38761434920635,
#  'total_slippage': 68800.0,
#  'daily_slippage': 72.80423280423281,
#  'total_turnover': 894209852.0,
#  'daily_turnover': 946253.8116402116,
#  'total_trade_count': 688,
#  'daily_trade_count': 0.728042328042328,
#  'total_return': -9.469529556000023,
#  'annual_return': -2.404959887238101,
#  'daily_return': -0.010527375868848247,
#  'return_std': 0.4017486032735663,
#  'sharpe_ratio': -0.40594890523167904,
#  'return_drawdown_ratio': -0.5985040648908885}

# %%
engine.show_chart()

# %%
df.to_csv('./test.csv')
